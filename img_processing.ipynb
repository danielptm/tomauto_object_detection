# %%
import img_processing.utils as utils
import time
path = "big_arrows/created/cropped_object.jpg"

# %%
t1 = time.time()

np_img = utils.create_img_np_array(path)
out = utils.shape_to_black_background_to_white(np_img)

approx = utils.get_corners(out)
val = approx.tolist()
unpacked = utils.flatten_double_array(val)
pq = utils.get_furthest_pts(unpacked)
pts = utils.set_pts(pq)
t2 = time.time()

print('time, ', t2 - t1)
print('dots, ', len(val))
utils.render_dots(out, val)
utils.show_image(out)
# Out:
# time,  0.005010366439819336
# dots,  7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 16
#      14 print('dots, ', len(val))
#      15 utils.render_dots(out, val)
# ---> 16 utils.show_image(out)
#
# File /snap/pycharm-professional/548/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:755, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     753 # if thread has a suspend flag, we suspend with a busy wait
#     754 if info.pydev_state == STATE_SUSPEND:
# --> 755     self.do_wait_suspend(thread, frame, event, arg)
#     756     # No need to reset frame.f_trace to keep the same trace function.
#     757     return self.trace_dispatch
#
# File /snap/pycharm-professional/548/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:412, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     411 def do_wait_suspend(self, *args, **kwargs):
# --> 412     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File /snap/pycharm-professional/548/plugins/python-ce/helpers/pydev/pydevd.py:1196, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1193         from_this_thread.append(frame_id)
#    1195 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1196     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /snap/pycharm-professional/548/plugins/python-ce/helpers/pydev/pydevd.py:1211, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1208             self._call_mpl_hook()
#    1210         self.process_internal_commands()
# -> 1211         time.sleep(0.01)
#    1213 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1215 # process any stepping instructions
#
# KeyboardInterrupt:
