# %%
import img_processing.utils as utils
import time

from img_processing.utils import ArrowParser

path = "big_arrows/created/cropped_object.jpg"

# %%
t1 = time.time()

np_img = utils.create_gray_image_from_path(path)
out = utils.remove_background_and_make_foreground_white(np_img)

ap = ArrowParser(out)

# res = ap.get_corners()
# val = approx.tolist()
# unpacked = utils.flatten_double_array(val)
pq = ap.set_pts()
ap.get_midpoint()
ap.get_direction_degrees()
# flattened = utils.flatten_array_all(pq)
# pts = utils.set_pts(flattened)
# t2 = time.time()

# print('time, ', t2 - t1)
# print('dots, ', len(val))
# utils.render_dots(out, val)
utils.show_image(out)
print('angle: ', ap.angle)
# Out:
# angle:  102.38075692880717
