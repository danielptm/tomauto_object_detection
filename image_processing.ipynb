# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")
model.train(data="YOLODataset/dataset.yaml", pretrained=False, epochs=300, imgsz=640, device=0, verbose=False, project='/home/daniel/projects/tomauto_object_detection/runs/train', name='arrows')
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.3 torch-2.9.0+cu128 CUDA:0 (NVIDIA RTX 2000 Ada Generation, 15947MiB)
# ...

# %%
# model = YOLO("runs/train/arrows/weights/best.pt")
# model.predict('big_arrows/rando/frame0281.png', save=True, imgsz=640, conf=0.1, project='/home/daniel/projects/tomauto_object_detection/runs/predict', name='arrows')
